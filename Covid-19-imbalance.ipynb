# %%
# Covid Project

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter("ignore")

# %%
df=pd.read_csv("covid-19.csv")
df=df.loc[:,~df.columns.str.contains("^Unnamed")]
df.head()
# Out:
#   Rank   NCT Number                                              Title  \
# 0    1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1    2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2    3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3    4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4    5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# 1                               SARS-CoV-2 Infection
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5786 entries, 0 to 5785
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     5786 non-null   object
#  1   NCT Number               5786 non-null   object
#  2   Title                    5786 non-null   object
#  3   Acronym                  2483 non-null   object
#  4   Status                   5786 non-null   object
#  5   Study Results            5786 non-null   object
#  6   Conditions               5786 non-null   object
#  7   Interventions            4900 non-null   object
#  8   Outcome Measures         5751 non-null   object
#  9   Sponsor/Collaborators    5786 non-null   object
#  10  Gender                   5776 non-null   object
#  11  Age                      5786 non-null   object
#  12  Phases                   3325 non-null   object
#  13  Enrollment               5752 non-null   object
# ...

# %%
df.columns.tolist()
# Out:
# ['Rank',
#  'NCT Number',
#  'Title',
#  'Acronym',
#  'Status',
#  'Study Results',
#  'Conditions',
#  'Interventions',
#  'Outcome Measures',
#  'Sponsor/Collaborators',
#  'Gender',
#  'Age',
#  'Phases',
#  'Enrollment',
#  'Funded Bys',
#  'Study Type',
#  'Study Designs',
#  'Other IDs',
#  'Start Date',
#  'Primary Completion Date',
#  'Completion Date',
#  'First Posted',
#  'Results First Posted',
#  'Last Update Posted',
#  'Locations',
#  'Study Documents',
#  'URL']

# %%
df["Rank"].unique()
# Out:
# array([1, 2, 3, ..., '5781', '5782', '5783'], dtype=object)

# %%
df["Rank"].nunique()
# Out:
# 5786

# %%
df["NCT Number"].unique()
# Out:
# array(['NCT04785898', 'NCT04595136', 'NCT04395482', ..., 'NCT04740229',
#        'NCT04804917', 'NCT04680000'], dtype=object)

# %%
df["NCT Number"].nunique()
# Out:
# 5786

# %%
df["Title"].unique()
# Out:
# array(['Diagnostic Performance of the ID Now™ COVID-19 Screening Test Versus Simplexa™ COVID-19 Direct Assay',
#        'Study to Evaluate the Efficacy of COVID19-0001-USR in Patients With Mild/or Moderate COVID-19 Infection in Outpatient',
#        'Lung CT Scan Analysis of SARS-CoV2 Induced Lung Injury', ...,
#        'Moderate-intensity Flow-based Yoga Effects on Cognition and Stress',
#        '3-year Follow-up of the Mind My Mind RCT',
#        'Chronic Pain Management In Primary Care Using Behavioral Health Consultants'],
#       dtype=object)

# %%
df["Title"].nunique()
# Out:
# 5778

# %%
df["Acronym"].unique()
# Out:
# array(['COVID-IDNow', 'COVID-19', 'TAC-COVID19', ..., 'CRISP', 'cSLE',
#        'MindMyMindFU'], dtype=object)

# %%
df["Acronym"].nunique()
# Out:
# 2341

# %%
df["Acronym"].value_counts()
# Out:
# Acronym
# COVID-19        47
# PROTECT          7
# CORONA           6
# RECOVER          5
# Covid-19         5
#                 ..
# ASD              1
# VICO             1
# LICORNE          1
# LOSVID           1
# MindMyMindFU     1
# Name: count, Length: 2341, dtype: int64

# %%
df["Status"].unique()
# Out:
# array(['Active, not recruiting', 'Not yet recruiting', 'Recruiting',
#        'Enrolling by invitation', 'Suspended', 'Completed', 'Withdrawn',
#        'Terminated', 'No longer available', 'Available',
#        'Approved for marketing', ' Kansas City',
#        'Temporarily not available', ' Majadahonda /ID# 157573',
#        ' Saint-Petersburg'], dtype=object)

# %%
df["Status"].value_counts()
# Out:
# Status
# Recruiting                   2805
# Completed                    1025
# Not yet recruiting           1004
# Active, not recruiting        526
# Enrolling by invitation       181
# Withdrawn                     107
# Terminated                     74
# Suspended                      27
# Available                      19
# No longer available            12
# Approved for marketing          2
#  Kansas City                    1
# Temporarily not available       1
#  Majadahonda /ID# 157573        1
#  Saint-Petersburg               1
# Name: count, dtype: int64

# %%
df["Study Results"].unique()
# Out:
# array(['No Results Available', 'Has Results', ' Missouri', ' Majadahonda',
#        ' Russian Federation|Medical University REAVIZ'], dtype=object)

# %%
df["Study Results"].value_counts()
# Out:
# Study Results
# No Results Available                             5747
# Has Results                                        36
#  Missouri                                           1
#  Majadahonda                                        1
#  Russian Federation|Medical University REAVIZ       1
# Name: count, dtype: int64

# %%
df["Conditions"].unique()
# Out:
# array(['Covid19', 'SARS-CoV-2 Infection', 'covid19', ...,
#        'Community Acquired Pneumonia in Children|Antibiotic Stewardship',
#        'Stress|Psychological',
#        'Emotional Problem|Anxiety Disorder of Childhood|Depressive Symptoms|Behavior Problem of Childhood and Adolescence|Mental Health Disorder'],
#       dtype=object)

# %%
df["Conditions"].value_counts()
# Out:
# Conditions
# COVID-19                                                                                                                                    720
# Covid19                                                                                                                                     657
# COVID                                                                                                                                        95
# Covid-19                                                                                                                                     88
# SARS-CoV-2                                                                                                                                   52
#                                                                                                                                            ...
# ...

# %%
df["Interventions"].unique()
# Out:
# array(['Diagnostic Test: ID Now™ COVID-19 Screening Test',
#        'Drug: Drug COVID19-0001-USR|Drug: normal saline',
#        'Other: Lung CT scan analysis in COVID-19 patients', ...,
#        'Other: Antibiotic treatment|Other: No antibiotic treatment',
#        'Behavioral: Yoga',
#        'Behavioral: Brief Cognitive Behavioral Therapy for Chronic Pain (BCBT-CP)|Other: BCBT-CP Booster'],
#       dtype=object)

# %%
df["Interventions"].value_counts()
# Out:
# Interventions
# Other: No intervention                                                                              32
# Other: Questionnaire                                                                                24
# Other: Survey                                                                                       17
# Drug: Hydroxychloroquine                                                                            16
# Biological: Convalescent plasma                                                                     16
#                                                                                                     ..
# Drug: Losartan 50 mg and Spironolactone 25 mg pillules oral use                                      1
# Diagnostic Test: Asynchronies detection                                                              1
# Drug: N-acetylcysteine|Other: Peripheral Blood                                                       1
# ...

# %%
df["Outcome Measures"].unique()
# Out:
# array(['Evaluate the diagnostic performance of the ID Now ™ COVID-19 test carried out by nurses in an emergency department in comparison with the reference PCR test: Simplexa ™ COVID-19 Direct',
#        'Change on viral load results from baseline after using COVID19-0001-USR via nebulization',
#        'A qualitative analysis of parenchymal lung damage induced by COVID-19|A quantitative analysis of parenchymal lung damage induced by COVID-19|The potential impact of parenchymal morphological CT scans in patients with severe moderate respiratory failure.|Automated segmentation of lung scans of patients with COVID-19 and ARDS.|Knowledge of chest CT features in COVID-19 patients and their detail through the use of machine learning and other quantitative techniques.|The ability within which the analysis of artificial intelligence that uses deep learning models can be used to predict clinical outcomes',
#        ...,
# ...

# %%
df["Outcome Measures"].value_counts()
# Out:
# Outcome Measures
# Mortality                                                                                                                                                                                                                                                                                                                                         5
# Time to clinical improvement|Mortality|SpO2 Improvement|Incidence of new mechanical ventilation use|Duration of hospitalization|Cumulative incidence of serious adverse events                                                                                                                                                                    4
# ...

# %%
df["Sponsor/Collaborators"].unique()
# Out:
# array(['Groupe Hospitalier Paris Saint Joseph',
#        'United Medical Specialties', 'University of Milano Bicocca', ...,
#        'University of Illinois at Urbana-Champaign',
#        'Mental Health Services in the Capital Region, Denmark|Frederiksberg University Hospital|Defactum, Central Denmark Region|The Danish Mental Health Foundation',
#        'The University of Texas Health Science Center at San Antonio|Uniformed Services University of the Health Sciences|Massachusetts General Hospital|Defense Health Agency|59th Medical Wing|Brooke Army Medical Center|C.R.Darnall Army Medical Center'],
#       dtype=object)

# %%
df["Sponsor/Collaborators"].value_counts()
# Out:
# Sponsor/Collaborators
# Assistance Publique - Hôpitaux de Paris                                                                                                                                                                                                                78
# Assiut University                                                                                                                                                                                                                                      57
# University Hospital, Strasbourg, France                                                                                                                                                                                                                40
# ...

# %%
df["Gender"].unique()
# Out:
# array(['All', 'Female', 'Male', nan, " Lee's Summit",
#        ' Spain|Hospital General Universitario Alicante /ID# 159236',
#        ' Saratov'], dtype=object)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# All                                                           5567
# Female                                                         162
# Male                                                            44
#  Lee's Summit                                                    1
#  Spain|Hospital General Universitario Alicante /ID# 159236       1
#  Saratov                                                         1
# Name: count, dtype: int64

# %%
df["Age"].unique()
# Out:
# array(['18 Years and older \xa0 (Adult, Older Adult)',
#        'Child, Adult, Older Adult', '18 Years to 48 Years \xa0 (Adult)',
#        '18 Years to 75 Years \xa0 (Adult, Older Adult)',
#        '18 Years to 45 Years \xa0 (Adult)',
#        '18 Years to 99 Years \xa0 (Adult, Older Adult)',
#        '18 Years to 55 Years \xa0 (Adult)',
#        '15 Years and older \xa0 (Child, Adult, Older Adult)',
#        '18 Years to 80 Years \xa0 (Adult, Older Adult)',
#        '45 Years and older \xa0 (Adult, Older Adult)',
#        '20 Years to 100 Years \xa0 (Adult, Older Adult)',
#        '8 Years to 88 Years \xa0 (Child, Adult, Older Adult)',
#        '5 Years to 65 Years \xa0 (Child, Adult, Older Adult)',
#        'up to 99 Years \xa0 (Child, Adult, Older Adult)',
#        '18 Years to 85 Years \xa0 (Adult, Older Adult)',
#        '18 Years to 65 Years \xa0 (Adult, Older Adult)',
#        'up to 29 Days \xa0 (Child)',
#        '18 Years to 70 Years \xa0 (Adult, Older Adult)',
# ...

# %%
df["Age"].value_counts()
# Out:
# Age
# 18 Years and older   (Adult, Older Adult)             2885
# Child, Adult, Older Adult                              486
# 18 Years to 80 Years   (Adult, Older Adult)            221
# 18 Years to 65 Years   (Adult, Older Adult)            155
# 18 Years to 75 Years   (Adult, Older Adult)            135
#                                                       ...
# 1 Month to 30 Years   (Child, Adult)                     1
# 21 Years to 40 Years   (Adult)                           1
# 11 Years and older   (Child, Adult, Older Adult)         1
# 15 Years to 75 Years   (Child, Adult, Older Adult)       1
# 8 Years to 20 Years   (Child, Adult)                     1
# Name: count, Length: 420, dtype: int64

# %%
df["Phases"].unique()
# Out:
# array(['Not Applicable', 'Phase 1|Phase 2', nan, 'Early Phase 1',
#        'Phase 2|Phase 3', 'Phase 1', 'Phase 4', 'Phase 2', 'Phase 3',
#        ' United States|University of Kansas Cancer Center at North Kansas City Hospital',
#        ' Spain|Hospital Clinic de Barcelona /ID# 157552', ' Sochi'],
#       dtype=object)

# %%
df["Phases"].value_counts()
# Out:
# Phases
# Not Applicable                                                                     1354
# Phase 2                                                                             685
# Phase 3                                                                             450
# Phase 1                                                                             234
# Phase 2|Phase 3                                                                     200
# Phase 1|Phase 2                                                                     192
# Phase 4                                                                             161
# Early Phase 1                                                                        46
#  United States|University of Kansas Cancer Center at North Kansas City Hospital       1
#  Spain|Hospital Clinic de Barcelona /ID# 157552                                       1
#  Sochi                                                                                1
# ...

# %%
df["Enrollment"].unique()
# Out:
# array([1000.0, 60.0, 500.0, ..., '566', '396', '716'], dtype=object)

# %%
df["Enrollment"].value_counts()
# Out:
# Enrollment
# 100.0     289
# 200.0     197
# 60.0      141
# 50.0      135
# 30.0      131
#          ...
# 1574.0      1
# 1380.0      1
# 366.0       1
# 720         1
# 716         1
# Name: count, Length: 1218, dtype: int64

# %%
df["Funded Bys"].unique()
# Out:
# array(['Other', 'Industry', 'Industry|Other', 'Other|Industry',
#        'Other|U.S. Fed', 'NIH', 'Other|NIH', 'NIH|Other|Industry',
#        'NIH|Other', 'NIH|Industry', 'Industry|U.S. Fed', 'U.S. Fed|Other',
#        'Other|U.S. Fed|NIH', 'Industry|U.S. Fed|Other', ' Missouri',
#        'Other|NIH|U.S. Fed', 'Industry|NIH|Other',
#        'Industry|Other|U.S. Fed', 'Industry|NIH',
#        'Other|U.S. Fed|Industry', 'U.S. Fed', 'NIH|Industry|Other',
#        'NIH|Other|U.S. Fed|Industry', 'Industry|U.S. Fed|NIH',
#        'Other|Industry|NIH', 'Other|NIH|Industry', 'Industry|Other|NIH',
#        ' Spain|Hospital General Universitario Gregorio Maranon /ID# 161145',
#        ' St Petersburg'], dtype=object)

# %%
df["Funded Bys"].value_counts()
# Out:
# Funded Bys
# Other                                                                 4488
# Industry                                                               651
# Other|Industry                                                         216
# Industry|Other                                                         190
# Other|NIH                                                               97
# NIH                                                                     51
# Other|U.S. Fed                                                          25
# U.S. Fed                                                                15
# Industry|U.S. Fed                                                       10
# NIH|Industry                                                             6
# U.S. Fed|Other                                                           5
# NIH|Other                                                                5
# ...

# %%
df["Study Type"].unique()
# Out:
# array(['Interventional', 'Observational',
#        'Expanded Access:Treatment IND/Protocol',
#        'Expanded Access:Individual Patients|Intermediate-size Population',
#        'Expanded Access:Intermediate-size Population',
#        'Expanded Access:Intermediate-size Population|Treatment IND/Protocol',
#        ' United States|Delbert Day Cancer Institute at PCRMC',
#        'Expanded Access',
#        'Expanded Access:Individual Patients|Treatment IND/Protocol',
#        'Expanded Access:Individual Patients', ' Madrid',
#        ' Russian Federation|Oncology Center of Moskovskiy District'],
#       dtype=object)

# %%
df["Study Type"].value_counts()
# Out:
# Study Type
# Interventional                                                         3322
# Observational                                                          2427
# Expanded Access:Intermediate-size Population                             15
# Expanded Access:Treatment IND/Protocol                                    8
# Expanded Access:Intermediate-size Population|Treatment IND/Protocol       5
# Expanded Access:Individual Patients                                       3
# Expanded Access:Individual Patients|Intermediate-size Population          1
#  United States|Delbert Day Cancer Institute at PCRMC                      1
# Expanded Access                                                           1
# Expanded Access:Individual Patients|Treatment IND/Protocol                1
#  Madrid                                                                   1
#  Russian Federation|Oncology Center of Moskovskiy District                1
# Name: count, dtype: int64

# %%
df["Study Designs"].unique()
# Out:
# array(['Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)|Primary Purpose: Diagnostic',
#        'Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: Triple (Participant, Care Provider, Investigator)|Primary Purpose: Treatment',
#        'Observational Model: Cohort|Time Perspective: Retrospective',
#        'Observational Model: Cohort|Time Perspective: Prospective',
#        'Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)|Primary Purpose: Treatment',
#        'Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)|Primary Purpose: Prevention',
#        'Observational Model: Case-Control|Time Perspective: Retrospective',
#        'Allocation: Non-Randomized|Intervention Model: Parallel Assignment|Masking: None (Open Label)|Primary Purpose: Diagnostic',
# ...

# %%
df["Study Designs"].value_counts()
# Out:
# Study Designs
# Observational Model: Cohort|Time Perspective: Prospective                                                                                                                     1011
# Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: None (Open Label)|Primary Purpose: Treatment                                                           572
# Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: Quadruple (Participant, Care Provider, Investigator, Outcomes Assessor)|Primary Purpose: Treatment     312
# Observational Model: Cohort|Time Perspective: Retrospective                                                                                                                    282
# Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)|Primary Purpose: Treatment                                                              241
# ...

# %%
df["Other IDs"].unique()
# Out:
# array(['COVID-IDNow', 'COVID19-0001-USR', 'TAC-COVID19', ..., '21584',
#        'MHSCRDenmark, F-61502-03-1', 'HSC20200520H'], dtype=object)

# %%
df["Other IDs"].value_counts()
# Out:
# Other IDs
# 1                                17
# COVID-19                          6
# 2                                 6
# 3                                 4
# H-20021500                        3
#                                  ..
# HUM00186126|3P30AG024824-16S1     1
# OLFATO001                         1
# LSH-20-002                        1
# 68/2020                           1
# HSC20200520H                      1
# Name: count, Length: 5721, dtype: int64

# %%
df["Start Date"].unique()
# Out:
# array(['November 9, 2020', 'November 2, 2020', 'May 7, 2020',
#        'May 25, 2020', 'May 5, 2020', 'August 1, 2020', 'Sep-20',
#        'November 16, 2020', 'September 22, 2020', 'April 7, 2020',
#        'April 28, 2020', 'April 16, 2020', 'November 17, 2020',
#        'June 11, 2020', 'December 24, 2020', 'April 27, 2020',
#        'October 13, 2020', 'March 24, 2021', 'December 1, 2020',
#        'June 1, 2020', 'November 14, 2020', 'April 4, 2020',
#        'August 10, 2020', 'April 8, 2020', 'January 12, 2021',
#        'November 8, 2020', 'April 30, 2020', 'June 9, 2020',
#        'March 1, 2020', 'April 17, 2020', 'May 18, 2020', 'July 3, 2020',
#        'May 1, 2020', 'Jan-21', 'February 7, 2021', 'May 8, 2020',
#        'Feb-21', 'August 24, 2020', 'Apr-21', 'June 22, 2020', 'May-21',
#        'January 27, 2021', 'October 1, 2020', 'March 23, 2020',
#        'September 19, 2020', 'April 1, 2020', 'October 30, 2020',
# ...

# %%
df["Primary Completion Date"].unique()
# Out:
# array(['December 22, 2020', 'December 15, 2020', 'June 15, 2021',
#        'July 31, 2020', 'May-21', 'November 30, 2020', 'Oct-21',
#        'February 16, 2021', 'December 30, 2021', 'April 6, 2021',
#        'Jul-20', 'March 1, 2021', 'December 31, 2021', 'October 16, 2020',
#        'October 24, 2021', 'Oct-20', 'October 17, 2020', 'Jul-21',
#        'July 31, 2021', 'May 10, 2021', 'December 1, 2020',
#        'May 20, 2020', 'Jun-21', 'April 8, 2021', 'January 12, 2022',
#        'December 29, 2020', 'April 30, 2021', 'June 30, 2021',
#        'April 1, 2020', 'Apr-21', 'July 24, 2020', 'June 30, 2020',
#        'November 29, 2020', 'January 30, 2021', 'September 30, 2020',
#        'Jan-23', 'May 31, 2022', 'April 30, 2023', 'March 24, 2021',
#        'Sep-21', 'Mar-22', 'August 31, 2021', 'June 30, 2022',
#        'July 1, 2020', 'October 1, 2021', 'March 31, 2021', 'Nov-20',
#        'July 10, 2020', 'January 9, 2021', 'Jan-21', 'March 31, 2022',
# ...

# %%
df["Completion Date"].unique()
# Out:
# array(['April 30, 2021', 'January 29, 2021', 'June 15, 2021',
#        'August 31, 2020', 'May-21', 'December 30, 2020', 'Jun-22',
#        'May 16, 2021', 'December 30, 2021', 'April 6, 2021', 'Aug-20',
#        'March 1, 2021', 'June 30, 2022', 'October 16, 2020',
#        'October 24, 2021', 'Oct-20', 'October 17, 2020', 'Oct-21',
#        'July 31, 2021', 'May 10, 2021', 'December 31, 2020',
#        'July 14, 2020', 'Jul-21', 'April 8, 2026', 'January 12, 2024',
#        'December 29, 2023', 'June 30, 2021', 'April 30, 2020', 'Apr-22',
#        'July 24, 2020', 'January 30, 2021', 'December 31, 2021', 'Jan-23',
#        'Feb-22', 'Jun-21', 'May 31, 2022', 'June 1, 2023',
#        'March 24, 2021', 'Nov-21', 'September 30, 2020', 'Sep-22',
#        'September 1, 2020', 'October 1, 2021', 'September 30, 2021',
#        'Nov-20', 'November 30, 2020', 'Sep-21', 'Jan-21',
#        'March 31, 2022', 'July 28, 2021', 'August 30, 2020',
# ...

# %%
df.isnull().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    3303
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               886
# Outcome Measures             35
# Sponsor/Collaborators         0
# Gender                       10
# Age                           0
# Phases                     2461
# Enrollment                   34
# Funded Bys                    0
# Study Type                    0
# Study Designs                35
# Other IDs                     1
# Start Date                   34
# Primary Completion Date      36
# Completion Date              36
# First Posted                  0
# Results First Posted       5747
# Last Update Posted            0
# Locations                   585
# Study Documents            5601
# URL                           3
# dtype: int64

# %%
df.columns.tolist()
# Out:
# ['Rank',
#  'NCT Number',
#  'Title',
#  'Acronym',
#  'Status',
#  'Study Results',
#  'Conditions',
#  'Interventions',
#  'Outcome Measures',
#  'Sponsor/Collaborators',
#  'Gender',
#  'Age',
#  'Phases',
#  'Enrollment',
#  'Funded Bys',
#  'Study Type',
#  'Study Designs',
#  'Other IDs',
#  'Start Date',
#  'Primary Completion Date',
#  'Completion Date',
#  'First Posted',
#  'Results First Posted',
#  'Last Update Posted',
#  'Locations',
#  'Study Documents',
#  'URL']

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5781    False
# 5782    False
# 5783    False
# 5784    False
# 5785    False
# Length: 5786, dtype: bool

# %%
df["Acronym"].fillna("Not Available",inplace=True)

# %%
df["Acronym"].isnull().sum()
# Out:
# 0

# %%
df["Interventions"].fillna("Unknown",inplace=True)

# %%
df["Interventions"].isnull().sum()
# Out:
# 0

# %%
df["Gender"].fillna("All",inplace=True)

# %%
df["Outcome Measures"].fillna("Not Reported",inplace=True)

# %%
df["Phases"].fillna("Not Specified",inplace=True)

# %%
df["Phases"].isnull().sum()
# Out:
# 0

# %%
df["Study Designs"].fillna("Not Specified",inplace=True)

# %%
df["Study Designs"].isnull().sum()
# Out:
# 0

# %%
df["Locations"].fillna("Unknown",inplace=True)

# %%
df["Locations"].isnull().sum()
# Out:
# 0

# %%
df["Enrollment"]=pd.to_numeric(df["Enrollment"],errors="coerce")
df["Enrollment"].fillna(df["Enrollment"].median(),inplace=True)

# %%
df["Enrollment"]=df["Enrollment"].astype(int)

# %%
df["Enrollment"]
# Out:
# 0       1000
# 1         60
# 2        500
# 3       2500
# 4         50
#         ...
# 5781     566
# 5782     200
# 5783      88
# 5784     396
# 5785     716
# Name: Enrollment, Length: 5786, dtype: int32

# %%
date_cols=["Start Date","Primary Completion Date","Completion Date"]
for col in date_cols:
    df[col]=pd.to_datetime(df[col],errors="coerce")
    df[col].fillna(df[col].median(),inplace=True)

# %%
drop_cols=["Other IDs","Results First Posted","Study Documents","URL"]
df.drop(columns=drop_cols,inplace=True,errors="ignore")

# %%
df.columns.tolist()
# Out:
# ['Rank',
#  'NCT Number',
#  'Title',
#  'Acronym',
#  'Status',
#  'Study Results',
#  'Conditions',
#  'Interventions',
#  'Outcome Measures',
#  'Sponsor/Collaborators',
#  'Gender',
#  'Age',
#  'Phases',
#  'Enrollment',
#  'Funded Bys',
#  'Study Type',
#  'Study Designs',
#  'Start Date',
#  'Primary Completion Date',
#  'Completion Date',
#  'First Posted',
#  'Last Update Posted',
#  'Locations']

# %%
df.isnull().sum()
# Out:
# Rank                       0
# NCT Number                 0
# Title                      0
# Acronym                    0
# Status                     0
# Study Results              0
# Conditions                 0
# Interventions              0
# Outcome Measures           0
# Sponsor/Collaborators      0
# Gender                     0
# Age                        0
# Phases                     0
# Enrollment                 0
# Funded Bys                 0
# Study Type                 0
# Study Designs              0
# Start Date                 0
# Primary Completion Date    0
# Completion Date            0
# First Posted               0
# Last Update Posted         0
# Locations                  0
# dtype: int64

# %%
df["Study Duration Days"]=(df["Completion Date"]-df["Start Date"]).dt.days

# %%
df["Study Duration Days"]
# Out:
# 0       172
# 1        88
# 2       404
# 3        98
# 4       360
#        ...
# 5781    403
# 5782    312
# 5783     79
# 5784    649
# 5785    312
# Name: Study Duration Days, Length: 5786, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5786 entries, 0 to 5785
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     5786 non-null   object
#  1   NCT Number               5786 non-null   object
#  2   Title                    5786 non-null   object
#  3   Acronym                  5786 non-null   object
#  4   Status                   5786 non-null   object
#  5   Study Results            5786 non-null   object
#  6   Conditions               5786 non-null   object
#  7   Interventions            5786 non-null   object
#  8   Outcome Measures         5786 non-null   object
#  9   Sponsor/Collaborators    5786 non-null   object
#  10  Gender                   5786 non-null   object
#  11  Age                      5786 non-null   object
#  12  Phases                   5786 non-null   object
#  13  Enrollment               5786 non-null   int32
# ...

# %%
def phase_level(phase):
    phase=str(phase).lower()
    if "phase 4" in phase:
        return 4
    elif "phase 3" in phase:
        return 3
    elif "phase 2" in phase:
        return 2
    elif "phase 1" in phase:
        return 1
    else:
        return 0
df["Phase_Level"]=df["Phases"].apply(phase_level)

# %%
df.head()
# Out:
#   Rank   NCT Number                                              Title  \
# 0    1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1    2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2    3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3    4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4    5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# 1                               SARS-CoV-2 Infection
# ...

# %%
from sklearn.preprocessing import LabelEncoder
import pickle

# %%
df["Overall Status"]=df["Status"].apply(lambda x:1 if x in ["Completed"] else 0)

# %%
study_type_encoder=LabelEncoder()
df["Study Designs"]=study_type_encoder.fit_transform(df["Study Designs"])
with open("study_type_encoder.pkl","wb")as f:
    pickle.dump(study_type_encoder,f)
print("Study Type classes:",study_type_encoder.classes_)
# Out:
# Study Type classes: [' Rolla' ' Spain|Hospital Clinico Universitario San Carlos /ID# 225352'
#  ' St Petersburg'
#  'Allocation: N/A|Intervention Model: Parallel Assignment|Masking: None (Open Label)|Primary Purpose: Treatment'
#  'Allocation: N/A|Intervention Model: Sequential Assignment|Masking: None (Open Label)|Primary Purpose: Diagnostic'
#  'Allocation: N/A|Intervention Model: Sequential Assignment|Masking: None (Open Label)|Primary Purpose: Prevention'
#  'Allocation: N/A|Intervention Model: Sequential Assignment|Masking: None (Open Label)|Primary Purpose: Supportive Care'
#  'Allocation: N/A|Intervention Model: Sequential Assignment|Masking: None (Open Label)|Primary Purpose: Treatment'
#  'Allocation: N/A|Intervention Model: Single Group Assignment|Masking: Double (Investigator, Outcomes Assessor)|Primary Purpose: Diagnostic'
#  'Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)|Primary Purpose: Basic Science'
# ...

# %%
df["Gender"]=df["Gender"].map({"All":0,"Male":1,"Female":2}).fillna(0)

# %%
df["Gender"]=df["Gender"].astype(int)

# %%
df["Is_Funded_Industry"]=df["Funded Bys"].str.contains("Industry",case=False,na=False).astype(int)
df["Is_Funded_Govt"]=df["Funded Bys"].str.contains("NIH|U.S. Gov|Goverment",case=False,na=False).astype(int)
df["Is_Funded_Other"]=df["Funded Bys"].str.contains("Other",case=False,na=False).astype(int)

# %%
df["Study Result"]=df["Study Results"].apply(lambda x:0 if x=="No Results Available" else 1)

# %%
print(df[["Status","Study Designs","Gender","Is_Funded_Industry","Is_Funded_Govt","Is_Funded_Other"]].head())
print(df.dtypes)
# Out:
#                    Status  Study Designs  Gender  Is_Funded_Industry  \
# 0  Active, not recruiting             11       0                   0
# 1      Not yet recruiting            196       0                   0
# 2              Recruiting            260       0                   0
# 3  Active, not recruiting            260       0                   1
# 4              Recruiting            259       2                   0
#
#    Is_Funded_Govt  Is_Funded_Other
# 0               0                1
# 1               0                1
# 2               0                1
# 3               0                0
# 4               0                1
# Rank                               object
# NCT Number                         object
# Title                              object
# Acronym                            object
# Status                             object
# Study Results                      object
# Conditions                         object
# ...

# %%
df.to_csv("Feature covid-19.csv",index=False)

# %%
df=pd.read_csv("Feature covid-19.csv")

# %%
features=["Phase_Level","Study Designs","Gender","Is_Funded_Industry","Is_Funded_Govt","Is_Funded_Other","Enrollment"]

# %%
x=df[features]
y=df["Overall Status"]

# %%
train=[]
test=[]
cv=[]
for i in range(0,40):
    from sklearn.model_selection import train_test_split
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    from sklearn.linear_model import LogisticRegression
    log=LogisticRegression()
    log.fit(x_train,y_train)
    y_pred_train=log.predict(x_train)
    y_pred_test=log.predict(x_test)
    from sklearn.metrics import accuracy_score
    train.append(accuracy_score(y_train,y_pred_train))
    test.append(accuracy_score(y_test,y_pred_test))
    from sklearn.model_selection import cross_val_score
    cv.append(cross_val_score(log,x_train,y_train,cv=5,scoring="accuracy").mean())
em=pd.DataFrame({"train":train,"test":test,"cv":cv})
gm=em[(abs(em["train"]-em["test"])<=0.05)&(abs(em["test"]-em["cv"])<=0.05)]
print("best_random_number:",gm[gm["cv"]==gm["cv"].max()].index.to_list()[0])
# Out:
# best_random_number: 22

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, f1_score
from xgboost import XGBClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

print("Before SMOTE:")
print(y_train.value_counts())

print("\nAfter SMOTE:")
print(y_train_smote.value_counts())
# Out:
# Before SMOTE:
# Overall Status
# 0    3808
# 1     820
# Name: count, dtype: int64
#
# After SMOTE:
# Overall Status
# 1    3808
# 0    3808
# Name: count, dtype: int64

# %%
xgb = XGBClassifier(
    eval_metric='logloss',
    random_state=42
)

xgb.fit(X_train_smote, y_train_smote)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred = xgb.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1 score:", f1_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7262521588946459
# F1 score: 0.3463917525773196
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.83       953
#            1       0.30      0.41      0.35       205
#
#     accuracy                           0.73      1158
#    macro avg       0.58      0.60      0.59      1158
# weighted avg       0.76      0.73      0.74      1158

# %%
train=[]
test=[]
cv=[]
for i in range(0,40):
    from sklearn.model_selection import train_test_split
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    from sklearn.linear_model import LogisticRegression
    log=LogisticRegression()
    log.fit(x_train,y_train)
    y_pred_train=log.predict(x_train)
    y_pred_test=log.predict(x_test)
    from sklearn.metrics import accuracy_score
    train.append(accuracy_score(y_train,y_pred_train))
    test.append(accuracy_score(y_test,y_pred_test))
    from sklearn.model_selection import cross_val_score
    cv.append(cross_val_score(log,x_train,y_train,cv=5,scoring="accuracy").mean())
em=pd.DataFrame({"train":train,"test":test,"cv":cv})
gm=em[(abs(em["train"]-em["test"])<=0.05)&(abs(em["test"]-em["cv"])<=0.05)]
print("best_random_number:",gm[gm["cv"]==gm["cv"].max()].index.to_list()[0])
# Out:
# best_random_number: 22

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=22)

# %%
y_train.value_counts()
# Out:
# Overall Status
# 0    3814
# 1     814
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score

# Logistic Regression with imbalance handling
l = LogisticRegression(class_weight='balanced',max_iter=1000,random_state=22)
l.fit(x_train, y_train)

# Predictions
y_train_pred = l.predict(x_train)
y_test_pred = l.predict(x_test)

# Evaluation
print("Train Accuracy:", accuracy_score(y_train, y_train_pred))
print("Cross Validation:", cross_val_score(l, x_train, y_train, cv=5, scoring="f1").mean())
print("Test Accuracy:", accuracy_score(y_test, y_test_pred))
print("\nClassification Report:\n", classification_report(y_test, y_test_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_test_pred))
# Out:
# Train Accuracy: 0.5300345721694036
# Cross Validation: 0.32658779743195404
# Test Accuracy: 0.5328151986183074
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.51      0.64       947
#            1       0.22      0.63      0.33       211
#
#     accuracy                           0.53      1158
#    macro avg       0.54      0.57      0.49      1158
# weighted avg       0.74      0.53      0.58      1158
#
#
# Confusion Matrix:
#  [[484 463]
#  [ 78 133]]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,f1_score, classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score
scaler = StandardScaler()
X_train_s = scaler.fit_transform(x_train)
X_test_s = scaler.transform(x_test)
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train_s, y_train)
y_pred = knn.predict(X_test_s)
print("KNN")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1:", f1_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# KNN
# Accuracy: 0.805699481865285
# F1: 0.17582417582417584
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89       947
#            1       0.39      0.11      0.18       211
#
#     accuracy                           0.81      1158
#    macro avg       0.61      0.54      0.53      1158
# weighted avg       0.75      0.81      0.76      1158

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(class_weight='balanced',max_depth=8,random_state=22)
dt.fit(x_train, y_train)
y_pred = dt.predict(x_test)
print("Decision Tree")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1:", f1_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Decision Tree
# Accuracy: 0.6666666666666666
# F1: 0.32280701754385965
#               precision    recall  f1-score   support
#
#            0       0.85      0.72      0.78       947
#            1       0.26      0.44      0.32       211
#
#     accuracy                           0.67      1158
#    macro avg       0.55      0.58      0.55      1158
# weighted avg       0.74      0.67      0.70      1158

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200,class_weight='balanced',random_state=22)
rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)
print("Random Forest")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1:", f1_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Random Forest
# Accuracy: 0.7815198618307426
# F1: 0.29526462395543174
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87       947
#            1       0.36      0.25      0.30       211
#
#     accuracy                           0.78      1158
#    macro avg       0.60      0.58      0.58      1158
# weighted avg       0.76      0.78      0.77      1158

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(n_estimators=200,random_state=22)
ada.fit(x_train, y_train)
y_pred = ada.predict(x_test)
print("AdaBoost")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1:", f1_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# AdaBoost
# Accuracy: 0.8212435233160622
# F1: 0.15510204081632653
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90       947
#            1       0.56      0.09      0.16       211
#
#     accuracy                           0.82      1158
#    macro avg       0.69      0.54      0.53      1158
# weighted avg       0.78      0.82      0.76      1158

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(n_estimators=200,random_state=22)
gb.fit(x_train, y_train)
y_pred = gb.predict(x_test)
print("Gradient Boosting")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1:", f1_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Gradient Boosting
# Accuracy: 0.8246977547495682
# F1: 0.21011673151750973
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90       947
#            1       0.59      0.13      0.21       211
#
#     accuracy                           0.82      1158
#    macro avg       0.71      0.55      0.56      1158
# weighted avg       0.79      0.82      0.78      1158

# %%
from xgboost import XGBClassifier
scale_pos_weight = y_train.value_counts()[0] / y_train.value_counts()[1]
xgb = XGBClassifier(scale_pos_weight=scale_pos_weight,eval_metric='logloss',random_state=42)
xgb.fit(x_train, y_train)
y_pred = xgb.predict(x_test)
print("XGBoost")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1:", f1_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# XGBoost
# Accuracy: 0.7331606217616581
# F1: 0.39766081871345027
#               precision    recall  f1-score   support
#
#            0       0.87      0.79      0.83       947
#            1       0.34      0.48      0.40       211
#
#     accuracy                           0.73      1158
#    macro avg       0.61      0.64      0.61      1158
# weighted avg       0.78      0.73      0.75      1158
